# %%
import pandas as pd 
import numpy as np

# %%
ds = pd.Series([10,20,30,40,50], index=['h','a','r','s','h'],dtype='float',name='harsh')
print(ds)
# Out:
# h    10.0
# a    20.0
# r    30.0
# s    40.0
# h    50.0
# Name: harsh, dtype: float64

# %%
ds = pd.Series((10,20,30,40,50), index=['h','a','r','s','h'],dtype='float',name='harsh')
print(ds)
# Out:
# h    10.0
# a    20.0
# r    30.0
# s    40.0
# h    50.0
# Name: harsh, dtype: float64

# %%
d = {1:"one",2:"two",3:"three",4:"four",5:"five"}
ds = pd.Series(d,name='harsh')
print(ds)
# Out:
# 1      one
# 2      two
# 3    three
# 4     four
# 5     five
# Name: harsh, dtype: object

# %%
a = np.array([10,20,30,40,50])
ds = pd.Series(a, index=['h','a','r','s','h'],dtype='float',name='harsh')
print(ds)
# Out:
# h    10.0
# a    20.0
# r    30.0
# s    40.0
# h    50.0
# Name: harsh, dtype: float64

# %%
ds = pd.DataFrame([['h','a','r','s','h'],
                          [10,20,30,40,50],
                          [1,2,3,4,5]],columns=['a','b','c','d','e'])
print(ds)
# Out:
#     a   b   c   d   e
# 0   h   a   r   s   h
# 1  10  20  30  40  50
# 2   1   2   3   4   5

# %%
ds = pd.DataFrame({'name':['v','h','a'],
                 'mark' :[9.8,10,11],
                 'cgpa':[10,10,9.6]},index=['A','B','C'])
print(ds)
# Out:
#   name  mark  cgpa
# A    v   9.8  10.0
# B    h  10.0  10.0
# C    a  11.0   9.6

# %%
df = pd.read_csv('train.csv')
print(df.index)
print(df.columns)
print(df.size)
print(df.shape)
print(df.values)
print(df.dtypes)
print(df.ndim)
df.set_index('Name')
df = df.reset_index()
# Out:
# RangeIndex(start=0, stop=891, step=1)
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# 10692
# (891, 12)
# [[1 0 3 ... 7.25 nan 'S']
#  [2 1 1 ... 71.2833 'C85' 'C']
#  [3 1 3 ... 7.925 nan 'S']
#  ...
#  [889 0 3 ... 23.45 nan 'S']
#  [890 1 1 ... 30.0 'C148' 'C']
#  [891 0 3 ... 7.75 nan 'Q']]
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# 2

# %%
df1 = pd.DataFrame({'name':['A','B','c'],
                   'mark':[10,20,30],
                   'cgpi':[1,2,3]},
                   index=['v','h','a'],
                   columns= ['name','mark','cgpi'])
df1.set_index('name',drop=True)
print(df1)
df.reset_index
print(df)
# Out:
#   name  mark  cgpi
# v    A    10     1
# h    B    20     2
# a    c    30     3
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
df1.set_index('name',drop=False)
# Out:
#      name  mark  cgpi index columns
# name
# A       A    10     1     v       p
# B       B    20     2     h       q
# c       c    30     3     a       r

# %%
df['Name']
print(type(df[['Name','Pclass']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.iloc[2,3]
# Out:
# 3

# %%
df.iloc[2]
# Out:
# index                               2
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                                26
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
df.iloc[2,]
# Out:
# index                               2
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                                26
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
df.iloc[1:10,2:5]
# Out:
#    Survived  Pclass                                               Name
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)

# %%
df.iloc[1:0]
# Out:
# Empty DataFrame
# Columns: [index, PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.loc['Heikkinen, Miss. Laina':'Saundercock, Mr. William Henry','PassengerId':'Age']
# Out:
#                                                    PassengerId  Survived  \
# Name
# Heikkinen, Miss. Laina                                       3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                 4         1
# Allen, Mr. William Henry                                     5         0
# Moran, Mr. James                                             6         0
# McCarthy, Mr. Timothy J                                      7         0
# Palsson, Master. Gosta Leonard                               8         0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# Nasser, Mrs. Nicholas (Adele Achem)                         10         1
# Sandstrom, Miss. Marguerite Rut                             11         1
# Bonnell, Miss. Elizabeth                                    12         1
# Saundercock, Mr. William Henry                              13         0
#
#                                                    Pclass     Sex   Age
# Name
# ...

# %%
df2 = pd.DataFrame([[10,40,70],
                    [20,50,80],
                    [30,60,90]],
                   index=['a','b','c'],
                   columns= ['p','q','r'])
print(df2)
df2.loc['b']
# Out:
#     p   q   r
# a  10  40  70
# b  20  50  80
# c  30  60  90
# p    20
# q    50
# r    80
# Name: b, dtype: int64

# %%
df2.loc['b','q']
# Out:
# 50

# %%
df2.loc['a':,'r']
# Out:
# a    70
# b    80
# c    90
# Name: r, dtype: int64

# %%
df2.loc['b','q']=100
print(df2)
# Out:
#     p    q   r
# a  10   40  70
# b  20  100  80
# c  30   60  90

# %%
df2['d']=df2['p']*df2['q']
print(df2)
# Out:
#     p    q   r     d
# a  10   40  70   400
# b  20  100  80  2000
# c  30   60  90  1800

# %%
df2.loc['a':'c','p':'r']=7
print(df2)
# Out:
#    p  q  r     d
# a  7  7  7   400
# b  7  7  7  2000
# c  7  7  7  1800

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-a84c0541e888> in <module>
# ----> 1 import seaborn as sns
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\rcmod.py in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#       8
#       9
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\palettes.py in <module>
#       7 from .external import husl
#       8
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11
#
# ...
